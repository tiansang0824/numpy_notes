# %% [markdown]
# # NumPy笔记ep01-开始使用NumPy

# %% [markdown]
# NumPy笔记，原视频来自[B站-黑马](https://www.bilibili.com/video/BV1Hd4y1C7uQ)。

# %% [markdown]
# ### 数据分析的三个主要工具
#
# 数据分析领域有三个主要工具：
#
# - NumPy
# - Pandas
# - Matplotlib
#
# 导包的时候一般是下面的格式：
#
#
# ```python
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# ```
#
# 因为写这个笔记的时候没有在虚拟环境中安装后两个库，所以就不在jupyter的代码块中写这段代码了。

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 查看np版本

np.__version__
# Out:
# '1.26.4'

# %%
# rgb图像都是由像素点组成的。
ellen_joe = plt.imread("./resources/ellen_joe.jpg")

ellen_joe
# Out:
# array([[[  2,  58, 169],
#         [  8,  73, 175],
#         [  7,  69, 172],
#         ...,
#         [  3,  69, 182],
#         [  3,  68, 184],
#         [ 13,  77, 177]],
#
#        [[ 18,  69, 178],
#         [ 16,  86, 181],
#         [ 10,  69, 173],
#         ...,
#         [  0,  49, 170],
#         [  3,  74, 178],
#         [  6,  74, 185]],
#
#        [[  5,  72, 176],
#         [  6,  62, 173],
#         [  4,  70, 164],
#         ...,
#         [  1,  75, 174],
#         [ 14,  82, 191],
#         [ 12,  87, 188]],
#
#        ...,
#
#        [[242, 252, 254],
#         [242, 252, 254],
#         [242, 252, 254],
#         ...,
#         [243, 253, 255],
#         [243, 253, 255],
#         [244, 252, 255]],
#
#        [[242, 252, 254],
#         [243, 253, 255],
#         [242, 252, 254],
#         ...,
#         [242, 252, 254],
#         [244, 252, 255],
#         [244, 252, 255]],
#
#        [[241, 252, 254],
#         [242, 253, 255],
#         [241, 252, 254],
# ...

# %%
# 读取到的是一个多维数组
print(">> data type = ", type(ellen_joe))
# Out:
# >> data type =  <class 'numpy.ndarray'>

# %% [markdown]
# 利用shape查看多维数组形状，三个参数分别是：高度（行数）、宽度（列数）、通道数。

# %%
# 查看形状
ellen_joe.shape
# Out:
# (2160, 3840, 3)

# %%
# 显示图片
plt.imshow(ellen_joe)
